# %% [markdown]
# ### Get FRED Data by MSA

# %%
import pandas as pd
import numpy as np
import os
import requests
import json
import time
import matplotlib.pyplot as plt

# %% [markdown]
# Set up API Key

# %%
api_key = 'a37b50cd27afbc3ce23a81ddc5541dec'

# %% [markdown]
# Bring in List of Series

# %%
series = pd.read_csv('msa_series.csv')

# %%
keyword = 'Per Capita Personal Income'
reg_keyword = r'^Per Capita Personal Income'

# %%
income_series = series[series.title.str.match(reg_keyword)==True].reset_index(drop=True)

# %%
income_series.head()
# Out:
#             id realtime_start realtime_end  \
# 0  ANNI501PCPI     2021-12-04   2021-12-04
# 1  AUBU201PCPI     2021-12-04   2021-12-04
# 2  BIRM801PCPI     2021-12-04   2021-12-04
# 3  COLU913PCPI     2021-12-04   2021-12-04
# 4  DFHF901PCPI     2021-12-04   2021-12-04
#
#                                                title observation_start  \
# 0  Per Capita Personal Income in Anniston-Oxford-...        1969-01-01
# 1  Per Capita Personal Income in Auburn-Opelika, ...        1969-01-01
# 2  Per Capita Personal Income in Birmingham-Hoove...        1969-01-01
# 3  Per Capita Personal Income in Columbus, GA-AL ...        1969-01-01
# 4  Per Capita Personal Income in Daphne-Fairhope-...        1969-01-01
#
#   observation_end frequency frequency_short    units units_short  \
# 0      2020-01-01    Annual               A  Dollars           $
# 1      2020-01-01    Annual               A  Dollars           $
# 2      2020-01-01    Annual               A  Dollars           $
# 3      2020-01-01    Annual               A  Dollars           $
# 4      2020-01-01    Annual               A  Dollars           $
#
#        seasonal_adjustment seasonal_adjustment_short            last_updated  \
# 0  Not Seasonally Adjusted                       NSA  2021-11-16 07:41:49-06
# 1  Not Seasonally Adjusted                       NSA  2021-11-16 07:41:48-06
# 2  Not Seasonally Adjusted                       NSA  2021-11-16 07:38:17-06
# 3  Not Seasonally Adjusted                       NSA  2021-11-16 07:41:25-06
# 4  Not Seasonally Adjusted                       NSA  2021-11-16 07:41:23-06
#
#    popularity  group_popularity notes    state                        msa
# 0         1.0               1.0   NaN  Alabama        Anniston-Oxford, AL
# 1         1.0               1.0   NaN  Alabama         Auburn-Opelika, AL
# 2         7.0               7.0   NaN  Alabama      Birmingham-Hoover, AL
# 3         1.0               1.0   NaN  Alabama            Columbus, GA-AL
# 4         1.0               1.0   NaN  Alabama  Daphne-Fairhope-Foley, AL

# %%
def get_series(series_id, api_key):
    
    params = {
        'api_key' : api_key,
        'series_id' : series_id,
        'file_type': 'json'
    }
    
    endpoint = 'https://api.stlouisfed.org/fred/series/observations'
    
    response = requests.get(endpoint, params=params)
    observations = pd.DataFrame(json.loads(response.text)['observations'])
    
    return observations

# %%
income_series.columns
# Out:
# Index(['id', 'realtime_start', 'realtime_end', 'title', 'observation_start',
#        'observation_end', 'frequency', 'frequency_short', 'units',
#        'units_short', 'seasonal_adjustment', 'seasonal_adjustment_short',
#        'last_updated', 'popularity', 'group_popularity', 'notes', 'state',
#        'msa'],
#       dtype='object')

# %%
incomes = pd.DataFrame()
for idx in range(len(income_series)):
    series_df = get_series(income_series.id[idx], api_key)
    series_df['state'] = income_series.state[idx]
    series_df['msa'] = income_series.msa[idx]
    incomes = incomes.append(series_df)
    time.sleep(3)

# %%
plt.hist(incomes.groupby(['msa'])['value'].count())
# Out:
# (array([330.,   0.,   0.,   0.,   6.,  30.,   0.,   0.,   0.,   8.]),
#  array([ 43. ,  54.3,  65.6,  76.9,  88.2,  99.5, 110.8, 122.1, 133.4,
#         144.7, 156. ]),
#  <BarContainer object of 10 artists>)

# %%
#incomes.query("state=='Alabama' & msa == 'Dallas-Fort Worth-Arlington, TX'")
incomes.query("state=='Pennsylvania' & msa == 'Youngstown-Warren-Boardman, OH-PA'")
# Out:
#    realtime_start realtime_end        date  value         state  \
# 0      2021-12-07   2021-12-07  1969-01-01   3771  Pennsylvania
# 1      2021-12-07   2021-12-07  1970-01-01   3886  Pennsylvania
# 2      2021-12-07   2021-12-07  1971-01-01   4111  Pennsylvania
# 3      2021-12-07   2021-12-07  1972-01-01   4472  Pennsylvania
# 4      2021-12-07   2021-12-07  1973-01-01   5143  Pennsylvania
# 5      2021-12-07   2021-12-07  1974-01-01   5569  Pennsylvania
# 6      2021-12-07   2021-12-07  1975-01-01   6005  Pennsylvania
# 7      2021-12-07   2021-12-07  1976-01-01   6560  Pennsylvania
# 8      2021-12-07   2021-12-07  1977-01-01   7252  Pennsylvania
# 9      2021-12-07   2021-12-07  1978-01-01   7994  Pennsylvania
# 10     2021-12-07   2021-12-07  1979-01-01   8899  Pennsylvania
# 11     2021-12-07   2021-12-07  1980-01-01   9665  Pennsylvania
# 12     2021-12-07   2021-12-07  1981-01-01  10640  Pennsylvania
# 13     2021-12-07   2021-12-07  1982-01-01  10676  Pennsylvania
# 14     2021-12-07   2021-12-07  1983-01-01  11229  Pennsylvania
# 15     2021-12-07   2021-12-07  1984-01-01  12344  Pennsylvania
# 16     2021-12-07   2021-12-07  1985-01-01  13012  Pennsylvania
# 17     2021-12-07   2021-12-07  1986-01-01  13520  Pennsylvania
# 18     2021-12-07   2021-12-07  1987-01-01  13957  Pennsylvania
# 19     2021-12-07   2021-12-07  1988-01-01  15202  Pennsylvania
# 20     2021-12-07   2021-12-07  1989-01-01  16355  Pennsylvania
# 21     2021-12-07   2021-12-07  1990-01-01  16989  Pennsylvania
# 22     2021-12-07   2021-12-07  1991-01-01  17386  Pennsylvania
# 23     2021-12-07   2021-12-07  1992-01-01  18254  Pennsylvania
# 24     2021-12-07   2021-12-07  1993-01-01  18778  Pennsylvania
# 25     2021-12-07   2021-12-07  1994-01-01  19750  Pennsylvania
# 26     2021-12-07   2021-12-07  1995-01-01  20637  Pennsylvania
# 27     2021-12-07   2021-12-07  1996-01-01  21363  Pennsylvania
# 28     2021-12-07   2021-12-07  1997-01-01  22400  Pennsylvania
# 29     2021-12-07   2021-12-07  1998-01-01  23161  Pennsylvania
# 30     2021-12-07   2021-12-07  1999-01-01  23815  Pennsylvania
# 31     2021-12-07   2021-12-07  2000-01-01  24827  Pennsylvania
# 32     2021-12-07   2021-12-07  2001-01-01  25911  Pennsylvania
# 33     2021-12-07   2021-12-07  2002-01-01  26465  Pennsylvania
# 34     2021-12-07   2021-12-07  2003-01-01  27535  Pennsylvania
# 35     2021-12-07   2021-12-07  2004-01-01  28443  Pennsylvania
# 36     2021-12-07   2021-12-07  2005-01-01  29461  Pennsylvania
# 37     2021-12-07   2021-12-07  2006-01-01  31255  Pennsylvania
# 38     2021-12-07   2021-12-07  2007-01-01  32305  Pennsylvania
# 39     2021-12-07   2021-12-07  2008-01-01  33432  Pennsylvania
# 40     2021-12-07   2021-12-07  2009-01-01  31936  Pennsylvania
# 41     2021-12-07   2021-12-07  2010-01-01  33146  Pennsylvania
# 42     2021-12-07   2021-12-07  2011-01-01  35293  Pennsylvania
# 43     2021-12-07   2021-12-07  2012-01-01  36223  Pennsylvania
# 44     2021-12-07   2021-12-07  2013-01-01  36507  Pennsylvania
# 45     2021-12-07   2021-12-07  2014-01-01  37746  Pennsylvania
# 46     2021-12-07   2021-12-07  2015-01-01  38995  Pennsylvania
# 47     2021-12-07   2021-12-07  2016-01-01  39579  Pennsylvania
# 48     2021-12-07   2021-12-07  2017-01-01  40618  Pennsylvania
# 49     2021-12-07   2021-12-07  2018-01-01  42094  Pennsylvania
# 50     2021-12-07   2021-12-07  2019-01-01  43047  Pennsylvania
# 51     2021-12-07   2021-12-07  2020-01-01  46635  Pennsylvania
#
#                                   msa
# 0   Youngstown-Warren-Boardman, OH-PA
# 1   Youngstown-Warren-Boardman, OH-PA
# 2   Youngstown-Warren-Boardman, OH-PA
# 3   Youngstown-Warren-Boardman, OH-PA
# 4   Youngstown-Warren-Boardman, OH-PA
# 5   Youngstown-Warren-Boardman, OH-PA
# 6   Youngstown-Warren-Boardman, OH-PA
# 7   Youngstown-Warren-Boardman, OH-PA
# 8   Youngstown-Warren-Boardman, OH-PA
# 9   Youngstown-Warren-Boardman, OH-PA
# 10  Youngstown-Warren-Boardman, OH-PA
# 11  Youngstown-Warren-Boardman, OH-PA
# 12  Youngstown-Warren-Boardman, OH-PA
# 13  Youngstown-Warren-Boardman, OH-PA
# 14  Youngstown-Warren-Boardman, OH-PA
# 15  Youngstown-Warren-Boardman, OH-PA
# 16  Youngstown-Warren-Boardman, OH-PA
# 17  Youngstown-Warren-Boardman, OH-PA
# 18  Youngstown-Warren-Boardman, OH-PA
# 19  Youngstown-Warren-Boardman, OH-PA
# 20  Youngstown-Warren-Boardman, OH-PA
# 21  Youngstown-Warren-Boardman, OH-PA
# 22  Youngstown-Warren-Boardman, OH-PA
# 23  Youngstown-Warren-Boardman, OH-PA
# 24  Youngstown-Warren-Boardman, OH-PA
# 25  Youngstown-Warren-Boardman, OH-PA
# 26  Youngstown-Warren-Boardman, OH-PA
# 27  Youngstown-Warren-Boardman, OH-PA
# 28  Youngstown-Warren-Boardman, OH-PA
# 29  Youngstown-Warren-Boardman, OH-PA
# 30  Youngstown-Warren-Boardman, OH-PA
# 31  Youngstown-Warren-Boardman, OH-PA
# 32  Youngstown-Warren-Boardman, OH-PA
# 33  Youngstown-Warren-Boardman, OH-PA
# 34  Youngstown-Warren-Boardman, OH-PA
# 35  Youngstown-Warren-Boardman, OH-PA
# 36  Youngstown-Warren-Boardman, OH-PA
# 37  Youngstown-Warren-Boardman, OH-PA
# 38  Youngstown-Warren-Boardman, OH-PA
# 39  Youngstown-Warren-Boardman, OH-PA
# 40  Youngstown-Warren-Boardman, OH-PA
# 41  Youngstown-Warren-Boardman, OH-PA
# 42  Youngstown-Warren-Boardman, OH-PA
# 43  Youngstown-Warren-Boardman, OH-PA
# 44  Youngstown-Warren-Boardman, OH-PA
# 45  Youngstown-Warren-Boardman, OH-PA
# 46  Youngstown-Warren-Boardman, OH-PA
# 47  Youngstown-Warren-Boardman, OH-PA
# 48  Youngstown-Warren-Boardman, OH-PA
# 49  Youngstown-Warren-Boardman, OH-PA
# 50  Youngstown-Warren-Boardman, OH-PA
# 51  Youngstown-Warren-Boardman, OH-PA

# %%
incomes.groupby(['msa'])['value'].count()
# Out:
# msa
# Abilene, TX                           52
# Akron, OH                             52
# Albany, GA                            52
# Albany-Lebanon, OR                    52
# Albany-Schenectady-Troy, NY           52
#                                     ...
# Yakima, WA                            52
# York-Hanover, PA                      52
# Youngstown-Warren-Boardman, OH-PA    104
# Yuba City, CA                         52
# Yuma, AZ                              52
# Name: value, Length: 374, dtype: int64
