# %% [markdown]
# # Var Implementation
# This notebook walks through our Vector Auto Regression implementation as contained in the var_module.py module.

# %%
import var_module as var
# Out:
# WARNING (theano.configdefaults): g++ not available, if using conda: `conda install m2w64-toolchain`
# WARNING (theano.configdefaults): g++ not detected ! Theano will be unable to execute optimized C-implementations (for both CPU and GPU) and will default to Python implementations. Performance will be severely degraded. To remove this warning, set Theano flags cxx to an empty string.
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %% [markdown]
# ## Intialize our custom parameters
# Predictors must match available columns exactly. City must match an available city exactly

# %%
city = "Atlanta"
order = 4
data_path="pres-data.csv"
predictors = [
    'med_housing',
    'unemployment',
    'housing_listings',
    'population',
    'income'
]

key_var = 'med_housing'

# %% [markdown]
# ## Initialize & Preprocess data
# Ingest the raw data and generate the ouptut data frame with specified predictors

# %%
df = var.read_data(path=data_path, predictors=predictors)
df
# Out:
#      year_month  year  month     city state  med_housing  unemployment  \
# 0       2016.07  2016      7  Atlanta    GA  272000.0000           5.1
# 1       2016.08  2016      8  Atlanta    GA  269900.0000           5.1
# 2       2016.09  2016      9  Atlanta    GA  270168.0000           5.1
# 3       2016.10  2016     10  Atlanta    GA  269900.0000           5.1
# 4       2016.11  2016     11  Atlanta    GA  269900.0000           5.1
# ..          ...   ...    ...      ...   ...          ...           ...
# 232     2019.08  2019      8    Tulsa    OK  241185.7143           3.1
# 233     2019.09  2019      9    Tulsa    OK  242685.7143           3.1
# 234     2019.10  2019     10    Tulsa    OK  248950.0000           3.1
# 235     2019.11  2019     11    Tulsa    OK  248500.0000           3.0
# 236     2019.12  2019     12    Tulsa    OK  249725.0000           3.0
#
#      housing_listings  population   income
# 0             14848.0    5791.874  48657.0
# 1             13340.0    5791.874  48657.0
# 2             13404.0    5791.874  48657.0
# 3             12996.0    5791.874  48657.0
# 4             10848.0    5791.874  48657.0
# ..                ...         ...      ...
# 232            1320.0     999.348  56680.0
# 233            1116.0     999.348  56680.0
# 234            1200.0     999.348  56680.0
# 235             908.0     999.348  56680.0
# 236             900.0     999.348  56680.0
#
# [168 rows x 10 columns]

# %%
input_df = var.generate_time_data(df=df, city=city, order=order, predictors=predictors)
input_df.tail(15)
# Out:
# C:\Users\whetz\Documents\UVA MSDS\Bayes Machine Learning\Project\bayes-housing-project\final_code\var_module.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["step"] = [i for i in range(order)]
#       city_  year_month  med_housing_0  med_housing_1  med_housing_2  \
# 23  Atlanta     2018.10    339900.0000    330772.0000    325000.0000
# 24  Atlanta     2018.11    330772.0000    325000.0000    324900.0000
# 25  Atlanta     2018.12    325000.0000    324900.0000    319450.0000
# 26  Atlanta     2019.01    324900.0000    319450.0000    319116.0000
# 27  Atlanta     2019.02    319450.0000    319116.0000    315000.0000
# 28  Atlanta     2019.03    319116.0000    315000.0000    313950.0000
# 29  Atlanta     2019.04    315000.0000    313950.0000    317446.0000
# 30  Atlanta     2019.05    313950.0000    317446.0000    324237.1429
# 31  Atlanta     2019.06    317446.0000    324237.1429    329950.0000
# 32  Atlanta     2019.07    324237.1429    329950.0000    337510.0000
# 33  Atlanta     2019.08    329950.0000    337510.0000    334900.0000
# 34  Atlanta     2019.09    337510.0000    334900.0000    329450.0000
# 35  Atlanta     2019.10    334900.0000    329450.0000    323803.4286
# 36  Atlanta     2019.11    329450.0000    323803.4286    320000.0000
# 37  Atlanta     2019.12    323803.4286    320000.0000    322450.0000
#
#     med_housing_3  unemployment_0  unemployment_1  unemployment_2  \
# 23    324900.0000             3.8             3.7             3.7
# 24    319450.0000             3.7             3.7             3.6
# 25    319116.0000             3.7             3.6             3.7
# 26    315000.0000             3.6             3.7             3.7
# 27    313950.0000             3.7             3.7             3.7
# 28    317446.0000             3.7             3.7             3.7
# 29    324237.1429             3.7             3.7             3.7
# 30    329950.0000             3.7             3.7             3.6
# 31    337510.0000             3.7             3.6             3.6
# 32    334900.0000             3.6             3.6             3.5
# 33    329450.0000             3.6             3.5             3.4
# 34    323803.4286             3.5             3.4             3.3
# 35    320000.0000             3.4             3.3             3.2
# 36    322450.0000             3.3             3.2             3.2
# 37    325000.0000             3.2             3.2             3.1
#
#     unemployment_3  ...  population_3  income_0  income_1  income_2  income_3  \
# 23             3.6  ...      5951.394   53354.0   53354.0   53354.0   53354.0
# 24             3.7  ...      5951.394   53354.0   53354.0   53354.0   53354.0
# 25             3.7  ...      5951.394   53354.0   53354.0   53354.0   53354.0
# 26             3.7  ...      5951.394   53354.0   53354.0   53354.0   53354.0
# 27             3.7  ...      6027.231   53354.0   53354.0   53354.0   55668.0
# 28             3.7  ...      6027.231   53354.0   53354.0   55668.0   55668.0
# 29             3.6  ...      6027.231   53354.0   55668.0   55668.0   55668.0
# 30             3.6  ...      6027.231   55668.0   55668.0   55668.0   55668.0
# 31             3.5  ...      6027.231   55668.0   55668.0   55668.0   55668.0
# 32             3.4  ...      6027.231   55668.0   55668.0   55668.0   55668.0
# 33             3.3  ...      6027.231   55668.0   55668.0   55668.0   55668.0
# 34             3.2  ...      6027.231   55668.0   55668.0   55668.0   55668.0
# 35             3.2  ...      6027.231   55668.0   55668.0   55668.0   55668.0
# 36             3.1  ...      6027.231   55668.0   55668.0   55668.0   55668.0
# 37             3.1  ...      6027.231   55668.0   55668.0   55668.0   55668.0
#
#     med_housing  unemployment  housing_listings  population   income
# 23  319450.0000           3.7           17204.0    5951.394  53354.0
# 24  319116.0000           3.7           14788.0    5951.394  53354.0
# 25  315000.0000           3.7           11948.0    5951.394  53354.0
# 26  313950.0000           3.7           16000.0    6027.231  55668.0
# 27  317446.0000           3.7           17880.0    6027.231  55668.0
# 28  324237.1429           3.6           18440.0    6027.231  55668.0
# 29  329950.0000           3.6           20836.0    6027.231  55668.0
# 30  337510.0000           3.5           21296.0    6027.231  55668.0
# 31  334900.0000           3.4           19756.0    6027.231  55668.0
# 32  329450.0000           3.3           19136.0    6027.231  55668.0
# 33  323803.4286           3.2           18488.0    6027.231  55668.0
# 34  320000.0000           3.2           17536.0    6027.231  55668.0
# 35  322450.0000           3.1           17268.0    6027.231  55668.0
# 36  325000.0000           3.1           14440.0    6027.231  55668.0
# 37  319950.0000           3.1           11292.0    6027.231  55668.0
#
# [15 rows x 27 columns]

# %% [markdown]
# ## Generate pymc3 Model
# This will automatically write the code needed to generate a pymc3 model using our predictors that will be used for variational inference. See hidden cell for parameters in the model.

# %%
var.write_model_module(input_df=input_df, key_var=key_var)

import model_builder
model_comb = model_builder.build_model(input_df=input_df)
# Out:
# ['med_housing', 'unemployment', 'housing_listings', 'population', 'income']
# ['med_housing_0', 'med_housing_1', 'med_housing_2', 'med_housing_3', 'unemployment_0', 'unemployment_1', 'unemployment_2', 'unemployment_3', 'housing_listings_0', 'housing_listings_1', 'housing_listings_2', 'housing_listings_3', 'population_0', 'population_1', 'population_2', 'population_3', 'income_0', 'income_1', 'income_2', 'income_3']

# %%
model_comb
# Out:
# $$
#                 \begin{array}{rcl}
#                 \text{med_housing_0_med_housing} &\sim & \text{Normal}\\\text{med_housing_1_med_housing} &\sim & \text{Normal}\\\text{med_housing_2_med_housing} &\sim & \text{Normal}\\\text{med_housing_3_med_housing} &\sim & \text{Normal}\\\text{unemployment_0_med_housing} &\sim & \text{Normal}\\\text{unemployment_1_med_housing} &\sim & \text{Normal}\\\text{unemployment_2_med_housing} &\sim & \text{Normal}\\\text{unemployment_3_med_housing} &\sim & \text{Normal}\\\text{housing_listings_0_med_housing} &\sim & \text{Normal}\\\text{housing_listings_1_med_housing} &\sim & \text{Normal}\\\text{housing_listings_2_med_housing} &\sim & \text{Normal}\\\text{housing_listings_3_med_housing} &\sim & \text{Normal}\\\text{population_0_med_housing} &\sim & \text{Normal}\\\text{population_1_med_housing} &\sim & \text{Normal}\\\text{population_2_med_housing} &\sim & \text{Normal}\\\text{population_3_med_housing} &\sim & \text{Normal}\\\text{income_0_med_housing} &\sim & \text{Normal}\\\text{income_1_med_housing} &\sim & \text{Normal}\\\text{income_2_med_housing} &\sim & \text{Normal}\\\text{income_3_med_housing} &\sim & \text{Normal}\\\text{unemployment_0_unemployment} &\sim & \text{Normal}\\\text{unemployment_1_unemployment} &\sim & \text{Normal}\\\text{unemployment_2_unemployment} &\sim & \text{Normal}\\\text{unemployment_3_unemployment} &\sim & \text{Normal}\\\text{housing_listings_0_housing_listings} &\sim & \text{Normal}\\\text{housing_listings_1_housing_listings} &\sim & \text{Normal}\\\text{housing_listings_2_housing_listings} &\sim & \text{Normal}\\\text{housing_listings_3_housing_listings} &\sim & \text{Normal}\\\text{population_0_population} &\sim & \text{Normal}\\\text{population_1_population} &\sim & \text{Normal}\\\text{population_2_population} &\sim & \text{Normal}\\\text{population_3_population} &\sim & \text{Normal}\\\text{income_0_income} &\sim & \text{Normal}\\\text{income_1_income} &\sim & \text{Normal}\\\text{income_2_income} &\sim & \text{Normal}\\\text{income_3_income} &\sim & \text{Normal}\\\text{med_housing} &\sim & \text{Normal}\\\text{unemployment} &\sim & \text{Normal}\\\text{housing_listings} &\sim & \text{Normal}\\\text{population} &\sim & \text{Normal}\\\text{income} &\sim & \text{Normal}
#                 \end{array}
#                 $$

# %% [markdown]
# ## Generate posterior predictions for our coefficients
# This utilizes ADVI implementation of variational inference in pymc3 to generate our posterior predictions (this can take a few minutes)

# %%
parameters = var.generate_advi_posterior(model_comb)
parameters
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1233' class='' max='50000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       2.47% [1233/50000 01:51<1:13:46 Average Loss = 3,291.2]
#     </div>
# Interrupted at 1,233 [2%]: Average Loss = 3,292.2

# %% [markdown]
# # Run the forward model
# input the starting time period (formatted yyyy.mm) and the number of steps that you want to advance in your predictions. This will deliver a dataframe with your posterior predictions for however many steps you want to project to. The standard deviation dataframe gives you the spread of each of the predictions.

# %%
mean_df, std_df = var.run_projections(order=order, input=input_df, start_year_month=2017.12, samples=1000000, steps=10, parameters=parameters)
mean_df

# %%
std_df

# %% [markdown]
# # Visualize

# %%
var.generate_comparative_lineplot(df=df, mean_df=mean_df, start_year=2017, max_year=2018, city='Atlanta', order=4)

# %%
var.plot_uncertainty(mean_df=mean_df, std_df=std_df, steps=8)
