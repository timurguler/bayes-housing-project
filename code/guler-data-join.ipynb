# %%
import pandas as pd
import numpy as np
import requests
import json
import os
import time
import fred_msa
from datetime import date

# %%
csvs_to_ignore = ['msa_series.csv', 'msas-to-use.csv']

# %%
filepath = '..\\fred-data'
data_files = set(os.listdir(filepath)).difference(set(csvs_to_ignore))

# %%
all_data = {}
for file in data_files:
    all_data[file.replace('.csv', '')] = pd.read_csv(os.path.join(filepath, file))

# %%
series = pd.read_csv(os.path.join(filepath, 'msa_series.csv'))

# %%
series['clean_title'] = series.title.str.replace(':', ' -')
series.clean_title = [t.split(' in')[0] for t in series.clean_title]

# %%
ny = series.query("city == 'New York'")

frequencies = ny[['clean_title', 'frequency', 'seasonal_adjustment']]
used_series = frequencies[frequencies['clean_title'].isin(list(all_data.keys()))].reset_index(drop=True)

# %%
series_counts = pd.DataFrame(used_series.groupby(['clean_title'])['frequency'].count()).rename(columns={'frequency' : 'number'}).reset_index()
duplicates = series_counts[series_counts.number > 1].clean_title

# %%
list(duplicates)
# Out:
# ['All Employees - Accommodation and Food Services',
#  'All Employees - Administrative and Support and Waste Management and Remediation Services',
#  'All Employees - Education and Health Services',
#  'All Employees - Education and Health Services - Health Care and Social Assistance',
#  'All Employees - Financial Activities',
#  'All Employees - Financial Activities - Finance and Insurance',
#  'All Employees - Financial Activities - Insurance Carriers and Related Activities',
#  'All Employees - Goods Producing',
#  'All Employees - Government',
#  'All Employees - Government - Federal Government',
#  'All Employees - Government - Local Government',
#  'All Employees - Government - State Government',
#  'All Employees - Health Care - Ambulatory Health Care Services',
#  'All Employees - Health Care - Hospitals',
#  'All Employees - Information',
#  'All Employees - Information - Telecommunications',
#  'Housing Inventory - Median Home Size',
#  'Unemployment Rate']

# %%
series[(series.city == 'Chicago') & (series.title.str.contains('All Employees: Accomodation'))]
# Out:
# Empty DataFrame
# Columns: [id, realtime_start, realtime_end, title, observation_start, observation_end, frequency, frequency_short, units, units_short, seasonal_adjustment, seasonal_adjustment_short, last_updated, popularity, group_popularity, notes, msa, city, state, clean_title]
# Index: []

# %%
sorted_freq = frequencies.sort_values(['clean_title', 'frequency', 'seasonal_adjustment'], ascending=[True, False, False])

# %%
sorted_freq.groupby(['clean_title']).head(1)
# Out:
#                                            clean_title  frequency  \
# 206    All Employees - Accommodation and Food Services    Monthly
# 192  All Employees - Administrative and Support and...    Monthly
# 67       All Employees - Education and Health Services    Monthly
# 196  All Employees - Education and Health Services ...    Monthly
# 210                 All Employees - Federal Government     Annual
# ..                                                 ...        ...
# 110  Total Quantity Indexes for Real GDP for New Yo...     Annual
# 9                                Total Quarterly Wages  Quarterly
# 111  Total Real Gross Domestic Product for New York...     Annual
# 28                                  Unemployed Persons    Monthly
# 92                                   Unemployment Rate    Monthly
#
#               seasonal_adjustment
# 206           Seasonally Adjusted
# 192           Seasonally Adjusted
# 67            Seasonally Adjusted
# 196           Seasonally Adjusted
# 210       Not Seasonally Adjusted
# ..                            ...
# 110       Not Seasonally Adjusted
# 9             Seasonally Adjusted
# 111       Not Seasonally Adjusted
# 28        Not Seasonally Adjusted
# 92   Smoothed Seasonally Adjusted
#
# [116 rows x 3 columns]

# %%
dup_selections = dup_frequencies[(dup_frequencies.frequency == 'Monthly') & (dup_frequencies.seasonal_adjustment.str.contains('Not') == False)]

# %%
set(duplicates).difference(set(dup_selections.clean_title))
# Out:
# {'Housing Inventory - Median Home Size'}

# %%
string = ny[ny.clean_title=='Housing Inventory - Median Home Size'].title[55]

# %%
string.split(' in ')[0] + ' in ' + string.split(' in ')[1]
# Out:
# 'Housing Inventory: Median Home Size in Square Feet Year-Over-Year'

# %%
keyword_list = ['Per Capita Personal Income', 'Resident Population', 'Unemployment Rate',
                'New Private Housing Units Authorized by Building Permits',
                'Regional Price Parities']

ny = series.query("city == 'New York'")
ny_housing = ny.title[ny.title.str.contains('Housing Inventory')]
housing_series = [s.split(' in')[0] for s in ny_housing]

ny_employees = ny.title[ny.title.str.contains('All Employees')]
employees_series = list(np.unique([s.split(' in')[0] for s in ny_employees]))

keyword_list = housing_series + employees_series

# %%
keyword_list
# Out:
# ['Housing Inventory: Active Listing Count',
#  'Housing Inventory: Active Listing Count Month-Over-Month',
#  'Housing Inventory: Active Listing Count Year-Over-Year',
#  'Housing Inventory: Average Listing Price',
#  'Housing Inventory: Average Listing Price Month-Over-Month',
#  'Housing Inventory: Average Listing Price Year-Over-Year',
#  'Housing Inventory: Median Days on Market',
#  'Housing Inventory: Median Days on Market Month-Over-Month',
#  'Housing Inventory: Median Days on Market Year-Over-Year',
#  'Housing Inventory: Median Listing Price',
#  'Housing Inventory: Median Listing Price Month-Over-Month',
#  'Housing Inventory: Median Listing Price per Square Feet',
#  'Housing Inventory: Median Listing Price per Square Feet Month-Over-Month',
#  'Housing Inventory: Median Listing Price per Square Feet Year-Over-Year',
#  'Housing Inventory: Median Listing Price Year-Over-Year',
#  'Housing Inventory: Median Home Size',
#  'Housing Inventory: Median Home Size',
#  'Housing Inventory: Median Home Size',
#  'Housing Inventory: New Listing Count',
#  'Housing Inventory: New Listing Count Month-Over-Month',
#  'Housing Inventory: New Listing Count Year-Over-Year',
#  'Housing Inventory: Pending Listing Count',
#  'Housing Inventory: Pending Listing Count Month-Over-Month',
#  'Housing Inventory: Pending Listing Count Year-Over-Year',
#  'Housing Inventory: Price Increased Count',
#  'Housing Inventory: Price Increased Count Month-Over-Month',
#  'Housing Inventory: Price Increased Count Year-Over-Year',
#  'Housing Inventory: Price Reduced Count',
#  'Housing Inventory: Price Reduced Count Month-Over-Month',
#  'Housing Inventory: Price Reduced Count Year-Over-Year',
#  'All Employees: Accommodation and Food Services',
#  'All Employees: Administrative and Support and Waste Management and Remediation Services',
#  'All Employees: Education and Health Services',
#  'All Employees: Education and Health Services: Health Care and Social Assistance',
#  'All Employees: Federal Government',
#  'All Employees: Financial Activities',
#  'All Employees: Financial Activities: Finance and Insurance',
#  'All Employees: Financial Activities: Insurance Carriers and Related Activities',
#  'All Employees: Goods Producing',
#  'All Employees: Government',
#  'All Employees: Government: Federal Government',
#  'All Employees: Government: Local Government',
#  'All Employees: Government: State Government',
#  'All Employees: Health Care and Social Assistance',
#  'All Employees: Health Care: Ambulatory Health Care Services',
#  'All Employees: Health Care: Hospitals',
#  'All Employees: Information',
#  'All Employees: Information: Telecommunications',
#  'All Employees: Leisure and Hospitality',
#  'All Employees: Local Government',
#  'All Employees: Management of Companies and Enterprises',
#  'All Employees: Manufacturing',
#  'All Employees: Mining, Logging, and Construction',
#  'All Employees: Mining, Logging, and Construction: Specialty Trade Contractors',
#  'All Employees: Other Services',
#  'All Employees: Private Service Providing',
#  'All Employees: Professional and Business Services',
#  'All Employees: Professional, Scientific, and Technical Services',
#  'All Employees: Retail Trade',
#  'All Employees: Retail Trade: Department Stores',
#  'All Employees: Retail Trade: Food and Beverage Stores',
#  'All Employees: Retail Trade: General Merchandise Stores',
#  'All Employees: Service-Providing',
#  'All Employees: State Government',
#  'All Employees: Total Nonfarm',
#  'All Employees: Total Private',
#  'All Employees: Trade, Transportation, and Utilities',
#  'All Employees: Transportation and Utilities: Transportation, Warehousing, and Utilities',
#  'All Employees: Transportation and Warehousing',
#  'All Employees: Wholesale Trade',
#  'All Employees: Wholesale Trade: Merchant Wholesalers, Durable Goods',
#  'Average Hourly Earnings of All Employees: Total Private',
#  'Average Weekly Earnings of All Employees: Total Private',
#  'Average Weekly Hours of All Employees: Total Private']

# %%
ny[ny.clean_title.isin(pd.Series(keyword_list).str.replace(':', ' -'))]
# Out:
# Empty DataFrame
# Columns: [id, realtime_start, realtime_end, title, observation_start, observation_end, frequency, frequency_short, units, units_short, seasonal_adjustment, seasonal_adjustment_short, last_updated, popularity, group_popularity, notes, msa, city, state, clean_title]
# Index: []

# %%
pd.Series(keyword_list).str.replace(':', ' -')
# Out:
# 0              Housing Inventory - Active Listing Count
# 1     Housing Inventory - Active Listing Count Month...
# 2     Housing Inventory - Active Listing Count Year-...
# 3             Housing Inventory - Average Listing Price
# 4     Housing Inventory - Average Listing Price Mont...
#                             ...
# 69                      All Employees - Wholesale Trade
# 70    All Employees - Wholesale Trade - Merchant Who...
# 71    Average Hourly Earnings of All Employees - Tot...
# 72    Average Weekly Earnings of All Employees - Tot...
# 73    Average Weekly Hours of All Employees - Total ...
# Length: 74, dtype: object

# %%
ny.clean_title
# Out:
# 0                Housing Inventory: Active Listing Count
# 1      Housing Inventory: Active Listing Count Month-...
# 2      Housing Inventory: Active Listing Count Year-O...
# 3               Housing Inventory: Average Listing Price
# 4      Housing Inventory: Average Listing Price Month...
#                              ...
# 216                      All Employees: Local Government
# 217          All Employees: Government: Local Government
# 218                         Market Hotness: Supply Score
# 219    Quarterly Average of Total Assets for Commerci...
# 220    Quarterly Average of Total Loans for Commercia...
# Name: clean_title, Length: 221, dtype: object

# %%
list(all_data.keys())
# Out:
# ['Housing Inventory - Median Days on Market',
#  'Housing Inventory - New Listing Count Month-Over-Month',
#  'Housing Inventory - Median Listing Price',
#  'Housing Inventory - New Listing Count',
#  'All Employees - Information',
#  'Housing Inventory - Price Reduced Count Year-Over-Year',
#  'All Employees - Financial Activities - Insurance Carriers and Related Activities',
#  'Housing Inventory - Active Listing Count Month-Over-Month',
#  'Housing Inventory - Average Listing Price Year-Over-Year',
#  'Housing Inventory - Median Listing Price per Square Feet',
#  'All Employees - Information - Telecommunications',
#  'Housing Inventory - Price Increased Count Month-Over-Month',
#  'Housing Inventory - Price Increased Count Year-Over-Year',
#  'All Employees - Financial Activities',
#  'Housing Inventory - Median Listing Price Month-Over-Month',
#  'Housing Inventory - Median Listing Price per Square Feet Month-Over-Month',
#  'Housing Inventory - Pending Listing Count Month-Over-Month',
#  'All Employees - Financial Activities - Finance and Insurance',
#  'Housing Inventory - Price Increased Count',
#  'Housing Inventory - Average Listing Price',
#  'All Employees - Government - State Government',
#  'All Employees - Education and Health Services',
#  'Housing Inventory - Active Listing Count',
#  'All Employees - Health Care and Social Assistance',
#  'Resident Population',
#  'Housing Inventory - Median Days on Market Year-Over-Year',
#  'All Employees - Government - Local Government',
#  'New Private Housing Units Authorized by Building Permits',
#  'Regional Price Parities',
#  'Housing Inventory - Median Days on Market Month-Over-Month',
#  'All Employees - Government - Federal Government',
#  'All Employees - Health Care - Hospitals',
#  'Housing Inventory - Active Listing Count Year-Over-Year',
#  'Housing Inventory - Pending Listing Count',
#  'Housing Inventory - Pending Listing Count Year-Over-Year',
#  'Housing Inventory - Price Reduced Count',
#  'All Employees - Government',
#  'Housing Inventory - Median Listing Price per Square Feet Year-Over-Year',
#  'All Employees - Administrative and Support and Waste Management and Remediation Services',
#  'Housing Inventory - Median Listing Price Year-Over-Year',
#  'Housing Inventory - New Listing Count Year-Over-Year',
#  'Unemployment Rate',
#  'Per Capita Personal Income',
#  'All Employees - Federal Government',
#  'Housing Inventory - Average Listing Price Month-Over-Month',
#  'All Employees - Health Care - Ambulatory Health Care Services',
#  'Housing Inventory - Price Reduced Count Month-Over-Month',
#  'Housing Inventory - Median Home Size',
#  'All Employees - Goods Producing',
#  'All Employees - Education and Health Services - Health Care and Social Assistance',
#  'All Employees - Accommodation and Food Services']

# %%
all_data['Unemployment Rate']
# Out:
#              date  Unemployment Rate state  \
# 0      1990-01-01                5.4    NY
# 1      1991-01-01                7.3    NY
# 2      1992-01-01                9.1    NY
# 3      1993-01-01                8.4    NY
# 4      1994-01-01                7.2    NY
# ...           ...                ...   ...
# 19488  2021-06-01                2.9    ID
# 19489  2021-07-01                2.7    ID
# 19490  2021-08-01                2.7    ID
# 19491  2021-09-01                2.3    ID
# 19492  2021-10-01                2.1    ID
#
#                                          msa      city
# 0      New York-Newark-Jersey City, NY-NJ-PA  New York
# 1      New York-Newark-Jersey City, NY-NJ-PA  New York
# 2      New York-Newark-Jersey City, NY-NJ-PA  New York
# 3      New York-Newark-Jersey City, NY-NJ-PA  New York
# 4      New York-Newark-Jersey City, NY-NJ-PA  New York
# ...                                      ...       ...
# 19488                        Lewiston, ID-WA  Lewiston
# 19489                        Lewiston, ID-WA  Lewiston
# 19490                        Lewiston, ID-WA  Lewiston
# 19491                        Lewiston, ID-WA  Lewiston
# 19492                        Lewiston, ID-WA  Lewiston
#
# [19493 rows x 5 columns]

# %%
pop = pd.read_csv('..\\fred-data\Resident Population.csv')

# %%
income = pd.read_csv('..\\fred-data\Per Capita Personal Income.csv')

# %%
prices = pd.read_csv('..\\fred-data\Housing Inventory - Median Listing Price.csv')
listings = pd.read_csv('..\\fred-data\Housing Inventory - New Listing Count.csv')

# %%
drop_cols = ['state', 'city', 'title', 'id', 'frequency', 'seasonal_adjustment']

# %%
listings
# Out:
#             date  Housing Inventory: New Listing Count state  \
# 0     2016-07-01                                1400.0    SC
# 1     2016-08-01                                1364.0    SC
# 2     2016-09-01                                1296.0    SC
# 3     2016-10-01                                1140.0    SC
# 4     2016-11-01                                1136.0    SC
# ...          ...                                   ...   ...
# 1360  2021-07-01                                 716.0    KS
# 1361  2021-08-01                                 680.0    KS
# 1362  2021-09-01                                 624.0    KS
# 1363  2021-10-01                                 596.0    KS
# 1364  2021-11-01                                 476.0    KS
#
#                                   msa        city  \
# 0     Charleston-North Charleston, SC  Charleston
# 1     Charleston-North Charleston, SC  Charleston
# 2     Charleston-North Charleston, SC  Charleston
# 3     Charleston-North Charleston, SC  Charleston
# 4     Charleston-North Charleston, SC  Charleston
# ...                               ...         ...
# 1360                      Wichita, KS     Wichita
# 1361                      Wichita, KS     Wichita
# 1362                      Wichita, KS     Wichita
# 1363                      Wichita, KS     Wichita
# 1364                      Wichita, KS     Wichita
#
#                                                   title              id  \
# 0     Housing Inventory: New Listing Count in Charle...  NEWLISCOU16700
# 1     Housing Inventory: New Listing Count in Charle...  NEWLISCOU16700
# 2     Housing Inventory: New Listing Count in Charle...  NEWLISCOU16700
# 3     Housing Inventory: New Listing Count in Charle...  NEWLISCOU16700
# 4     Housing Inventory: New Listing Count in Charle...  NEWLISCOU16700
# ...                                                 ...             ...
# 1360  Housing Inventory: New Listing Count in Wichit...  NEWLISCOU48620
# 1361  Housing Inventory: New Listing Count in Wichit...  NEWLISCOU48620
# 1362  Housing Inventory: New Listing Count in Wichit...  NEWLISCOU48620
# 1363  Housing Inventory: New Listing Count in Wichit...  NEWLISCOU48620
# 1364  Housing Inventory: New Listing Count in Wichit...  NEWLISCOU48620
#
#      frequency      seasonal_adjustment
# 0      Monthly  Not Seasonally Adjusted
# 1      Monthly  Not Seasonally Adjusted
# 2      Monthly  Not Seasonally Adjusted
# 3      Monthly  Not Seasonally Adjusted
# 4      Monthly  Not Seasonally Adjusted
# ...        ...                      ...
# 1360   Monthly  Not Seasonally Adjusted
# 1361   Monthly  Not Seasonally Adjusted
# 1362   Monthly  Not Seasonally Adjusted
# 1363   Monthly  Not Seasonally Adjusted
# 1364   Monthly  Not Seasonally Adjusted
#
# [1365 rows x 9 columns]

# %%
dataset = pd.merge(prices, listings.drop(columns=drop_cols), how='left', on=['date','msa'])

# %%
dataset.date = pd.to_datetime(dataset.date)
dataset['year'] = [d.year for d in dataset.date]

# %%
income.date = pd.to_datetime(income.date)
income['year'] = [d.year for d in income.date]

pop.date = pd.to_datetime(pop.date)
pop['year'] = [d.year for d in pop.date]

# %%
dataset = pd.merge(dataset, income.drop(columns=['city', 'state', 'date']), how='left', on=['msa', 'year'])

# %%
dataset = pd.merge(dataset, pop.drop(columns=['city', 'state', 'date']), how='left', on=['msa', 'year'])

# %%
dataset['month'] = [d.month for d in dataset.date]

# %%
dataset = dataset[['msa', 'city', 'state', 'date', 'year', 'month',
        'Housing Inventory: Median Listing Price',
        'Housing Inventory: New Listing Count',
        'Per Capita Personal Income',
        'Resident Population']]

# %%
dataset.to_csv('..\\cleaned-data\\sample_data_set.csv', index=False)

# %%
listings.query("city=='Lewiston'").sort_values('date')
# Out:
#            date  Housing Inventory: New Listing Count state              msa  \
# 585  2016-07-01                                  96.0    ID  Lewiston, ID-WA
# 586  2016-08-01                                  84.0    ID  Lewiston, ID-WA
# 587  2016-09-01                                  68.0    ID  Lewiston, ID-WA
# 588  2016-10-01                                  56.0    ID  Lewiston, ID-WA
# 589  2016-11-01                                  48.0    ID  Lewiston, ID-WA
# ..          ...                                   ...   ...              ...
# 645  2021-07-01                                  56.0    ID  Lewiston, ID-WA
# 646  2021-08-01                                  84.0    ID  Lewiston, ID-WA
# 647  2021-09-01                                  64.0    ID  Lewiston, ID-WA
# 648  2021-10-01                                  72.0    ID  Lewiston, ID-WA
# 649  2021-11-01                                  48.0    ID  Lewiston, ID-WA
#
#          city                                              title  \
# 585  Lewiston  Housing Inventory: New Listing Count in Lewist...
# 586  Lewiston  Housing Inventory: New Listing Count in Lewist...
# 587  Lewiston  Housing Inventory: New Listing Count in Lewist...
# 588  Lewiston  Housing Inventory: New Listing Count in Lewist...
# 589  Lewiston  Housing Inventory: New Listing Count in Lewist...
# ..        ...                                                ...
# 645  Lewiston  Housing Inventory: New Listing Count in Lewist...
# 646  Lewiston  Housing Inventory: New Listing Count in Lewist...
# 647  Lewiston  Housing Inventory: New Listing Count in Lewist...
# 648  Lewiston  Housing Inventory: New Listing Count in Lewist...
# 649  Lewiston  Housing Inventory: New Listing Count in Lewist...
#
#                  id frequency      seasonal_adjustment
# 585  NEWLISCOU30300   Monthly  Not Seasonally Adjusted
# 586  NEWLISCOU30300   Monthly  Not Seasonally Adjusted
# 587  NEWLISCOU30300   Monthly  Not Seasonally Adjusted
# 588  NEWLISCOU30300   Monthly  Not Seasonally Adjusted
# 589  NEWLISCOU30300   Monthly  Not Seasonally Adjusted
# ..              ...       ...                      ...
# 645  NEWLISCOU30300   Monthly  Not Seasonally Adjusted
# 646  NEWLISCOU30300   Monthly  Not Seasonally Adjusted
# 647  NEWLISCOU30300   Monthly  Not Seasonally Adjusted
# 648  NEWLISCOU30300   Monthly  Not Seasonally Adjusted
# 649  NEWLISCOU30300   Monthly  Not Seasonally Adjusted
#
# [65 rows x 9 columns]

# %%
prices
# Out:
#             date  Housing Inventory: Median Listing Price state  \
# 0     2016-07-01                                428000.00    NY
# 1     2016-08-01                                424950.00    NY
# 2     2016-09-01                                427000.00    NY
# 3     2016-10-01                                434900.00    NY
# 4     2016-11-01                                439450.00    NY
# ...          ...                                      ...   ...
# 7177  2021-07-01                                     2.64    ID
# 7178  2021-08-01                                    21.01    ID
# 7179  2021-09-01                                     9.94    ID
# 7180  2021-10-01                                    21.37    ID
# 7181  2021-11-01                                    22.85    ID
#
#                                         msa      city
# 0     New York-Newark-Jersey City, NY-NJ-PA  New York
# 1     New York-Newark-Jersey City, NY-NJ-PA  New York
# 2     New York-Newark-Jersey City, NY-NJ-PA  New York
# 3     New York-Newark-Jersey City, NY-NJ-PA  New York
# 4     New York-Newark-Jersey City, NY-NJ-PA  New York
# ...                                     ...       ...
# 7177                        Lewiston, ID-WA  Lewiston
# 7178                        Lewiston, ID-WA  Lewiston
# 7179                        Lewiston, ID-WA  Lewiston
# 7180                        Lewiston, ID-WA  Lewiston
# 7181                        Lewiston, ID-WA  Lewiston
#
# [7182 rows x 5 columns]
